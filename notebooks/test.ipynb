# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/silver/geo/tracks/tracks_20251112_120852.parquet')

# %%
display(df.head())
display (df.tail())
print(df.info())
print(f"Dataframe has {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
#             track_name track_duration  track_listeners  \
# 0           Man I Need            184             6608
# 1      back to friends            199             6582
# 2              Dracula            205             6128
# 3                Tears            160             6036
# 4  The Fate of Ophelia            226             5987
#
#                              track_mbid  \
# 0  dd801b86-829e-4305-b80e-d90410a5b0b9
# 1  e374d8c3-da4b-42ce-84dd-26f7236907c3
# 2  5b1c893a-16da-4e3d-b9b7-6cc57afc360c
# 3  48f73745-0235-4244-9610-82f506fb40a7
# 4  8670a098-6ab7-4e18-8ac0-0ec7259151f8
#
#                                            track_url streamable.#text  \
# 0  https://www.last.fm/music/Olivia+Dean/_/Man+I+...                0
# 1  https://www.last.fm/music/sombr/_/back+to+friends                0
# 2    https://www.last.fm/music/Tame+Impala/_/Dracula                0
# 3  https://www.last.fm/music/Sabrina+Carpenter/_/...                0
# ...

# %%
df['chart_country'].value_counts()
# Out:
# chart_country
# australia         50
# canada            50
# france            50
# germany           50
# india             50
# italy             50
# japan             50
# netherlands       50
# spain             50
# united_kingdom    50
# united_states     50
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
#             track_name track_duration  track_listeners  \
# 0           Man I Need            184             6608
# 1      back to friends            199             6582
# 2              Dracula            205             6128
# 3                Tears            160             6036
# 4  The Fate of Ophelia            226             5987
#
#                              track_mbid  \
# 0  dd801b86-829e-4305-b80e-d90410a5b0b9
# 1  e374d8c3-da4b-42ce-84dd-26f7236907c3
# 2  5b1c893a-16da-4e3d-b9b7-6cc57afc360c
# 3  48f73745-0235-4244-9610-82f506fb40a7
# 4  8670a098-6ab7-4e18-8ac0-0ec7259151f8
#
#                                            track_url streamable.#text  \
# 0  https://www.last.fm/music/Olivia+Dean/_/Man+I+...                0
# 1  https://www.last.fm/music/sombr/_/back+to+friends                0
# 2    https://www.last.fm/music/Tame+Impala/_/Dracula                0
# 3  https://www.last.fm/music/Sabrina+Carpenter/_/...                0
# ...
